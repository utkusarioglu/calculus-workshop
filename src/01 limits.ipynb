# %%
from sympy import pi, limit, cos
from sympy.abc import x, y, i, t
from spb import plot, plot_parametric
from spb.defaults import cfg, set_defaults
import numpy as np
import pandas as pd

cfg["backend_2D"] = "bokeh"
cfg["bokeh"]["theme"] = "dark_minimal"
cfg["bokeh"]["sizing_mode"] = "fixed"
cfg["bokeh"]["minor_grid_line_alpha"] = 0.1
set_defaults(cfg)
# Out:
# /opt/conda/envs/default/lib/python3.10/site-packages/spb/defaults.py:259: UserWarning: Successfully written settings to /home/math/.local/share/spb/config.json
#   warnings.warn("Successfully written settings to {}".format(file_path))

# %%
DEFAULT_PARAMS = {
    "xlim": (-10, 10),
    "ylim": (-10, 10),
    "aspect": "equal",
    # "size": (7.3, 5),
    "show": False,
    "detect_poles": True
}

# %% [markdown]
# # Limits

# %% [markdown]
# ## Finding tangent to a curve
#
# We use an infinitesimal `d` to a target point `t` to determine a
# slope-intercept equation to the curve.

# %%
f_x = x**5 - 8 * x**3 + x**2 + 1
params = DEFAULT_PARAMS.copy()
params["ylim"] = (-50, 50)
params["xlim"] = (-pi, pi)
p_f_x = plot(f_x, **params)

t = 0.5  # Target point
d = 0.1  # Infinitesimal
a = t - d  # Approaching point. Meaning we are approaching from left
at_a = f_x.subs(x, a)
at_t = f_x.subs(x, t)
f_tan_slope = (at_a - at_t) / (a - t)
f_tan_int = at_t - (f_tan_slope * x).subs(x, t)
f_tan = f_tan_slope * x + f_tan_int
p_tan_x = plot(f_tan, **params)
(p_f_x + p_tan_x).show()
# Out:
#   <div class="bk-root" id="30824d32-fef3-4116-a6f4-e5bc36a685ac" data-root-id="20850"></div>

# %% [markdown]
# ## Limits using Sympy

# %%
f_x = (x**5 - 8 * x**3 + x**2 + 6) / (x - 1)
pos = limit(f_x, x, 1, "+")
neg = limit(f_x, x, 1, "-")
pos == neg
# Out:
# True

# %%
f_x = (x**2 + 4*x - 12) / (x**2 - 2*x)
params = DEFAULT_PARAMS.copy()
plot(f_x, **params).show()
limit(f_x, x, 2)
# Out:
#   <div class="bk-root" id="2d77f797-781f-4b1a-8d7a-2cbebfea3da7" data-root-id="1034"></div>
# 4

# %% [markdown]
# ## Numeric approach

# %%
t = 2
df = pd.DataFrame(
    columns=[
        "Infinitesimal Size",
        "Right Approach",
        "Right Value",
        "Left Approach",
        "Left Value",
    ]
).set_index("Infinitesimal Size")

for d in np.arange(1.0, 0.0, -0.02):
    right_arg = t - d
    right_res = f_x.subs(x, right_arg)
    left_arg = t + d
    left_res = f_x.subs(x, left_arg)
    row = pd.Series(
        {
            "Infinitesimal Size": d,
            "Right Approach": right_arg,
            "Right Value": right_res,
            "Left Approach": left_arg,
            "Left Value": left_res,
        }
    )
    df.loc[d] = row
df
# Out:
#                    Right Approach       Right Value Left Approach
# Infinitesimal Size
# 1.00                          1.0  7.00000000000000           3.0  \
# 0.98                         1.02  6.88235294117647          2.98
# 0.96                         1.04  6.76923076923077          2.96
# 0.94                         1.06  6.66037735849057          2.94
# 0.92                         1.08  6.55555555555556          2.92
# 0.90                          1.1  6.45454545454545           2.9
# 0.88                         1.12  6.35714285714286          2.88
# 0.86                         1.14  6.26315789473684          2.86
# 0.84                         1.16  6.17241379310345          2.84
# 0.82                         1.18  6.08474576271186          2.82
# 0.80                          1.2  6.00000000000000           2.8
# 0.78                         1.22  5.91803278688524          2.78
# 0.76                         1.24  5.83870967741935          2.76
# 0.74                         1.26  5.76190476190476          2.74
# 0.72                         1.28  5.68750000000000          2.72
# 0.70                          1.3  5.61538461538461           2.7
# 0.68                         1.32  5.54545454545455          2.68
# 0.66                         1.34  5.47761194029851          2.66
# 0.64                         1.36  5.41176470588235          2.64
# 0.62                         1.38  5.34782608695652          2.62
# 0.60                          1.4  5.28571428571428           2.6
# 0.58                         1.42  5.22535211267605          2.58
# 0.56                         1.44  5.16666666666667          2.56
# 0.54                         1.46  5.10958904109589          2.54
# 0.52                         1.48  5.05405405405405          2.52
# 0.50                          1.5  5.00000000000000           2.5
# 0.48                         1.52  4.94736842105263          2.48
# 0.46                         1.54  4.89610389610389          2.46
# 0.44                         1.56  4.84615384615384          2.44
# 0.42                         1.58  4.79746835443038          2.42
# 0.40                          1.6  4.75000000000000           2.4
# 0.38                         1.62  4.70370370370370          2.38
# 0.36                         1.64  4.65853658536585          2.36
# 0.34                         1.66  4.61445783132530          2.34
# 0.32                         1.68  4.57142857142857          2.32
# 0.30                          1.7  4.52941176470588           2.3
# 0.28                         1.72  4.48837209302325          2.28
# 0.26                         1.74  4.44827586206896          2.26
# 0.24                         1.76  4.40909090909091          2.24
# 0.22                         1.78  4.37078651685393          2.22
# 0.20                          1.8  4.33333333333333           2.2
# 0.18                         1.82  4.29670329670329          2.18
# 0.16                         1.84  4.26086956521739          2.16
# 0.14                         1.86  4.22580645161290          2.14
# 0.12                         1.88  4.19148936170212          2.12
# 0.10                          1.9  4.15789473684210           2.1
# 0.08                         1.92  4.12500000000000          2.08
# 0.06                         1.94  4.09278350515464          2.06
# 0.04                         1.96  4.06122448979591          2.04
# 0.02                         1.98  4.03030303030301          2.02
#
#                           Left Value
# Infinitesimal Size
# 1.00                3.00000000000000
# 0.98                3.01342281879195
# 0.96                3.02702702702703
# 0.94                3.04081632653061
# 0.92                3.05479452054795
# 0.90                3.06896551724138
# 0.88                3.08333333333333
# 0.86                3.09790209790210
# 0.84                3.11267605633803
# 0.82                3.12765957446809
# 0.80                3.14285714285714
# 0.78                3.15827338129496
# 0.76                3.17391304347826
# 0.74                3.18978102189781
# 0.72                3.20588235294118
# 0.70                3.22222222222222
# 0.68                3.23880597014925
# 0.66                3.25563909774436
# 0.64                3.27272727272727
# 0.62                3.29007633587786
# 0.60                3.30769230769231
# 0.58                3.32558139534884
# 0.56                3.34375000000000
# 0.54                3.36220472440945
# 0.52                3.38095238095238
# 0.50                3.40000000000000
# 0.48                3.41935483870968
# 0.46                3.43902439024390
# 0.44                3.45901639344262
# 0.42                3.47933884297521
# 0.40                3.50000000000000
# 0.38                3.52100840336135
# 0.36                3.54237288135593
# 0.34                3.56410256410256
# 0.32                3.58620689655173
# 0.30                3.60869565217391
# 0.28                3.63157894736842
# 0.26                3.65486725663717
# 0.24                3.67857142857143
# 0.22                3.70270270270270
# 0.20                3.72727272727273
# 0.18                3.75229357798165
# 0.16                3.77777777777778
# 0.14                3.80373831775701
# 0.12                3.83018867924528
# 0.10                3.85714285714286
# 0.08                3.88461538461538
# 0.06                3.91262135922331
# 0.04                3.94117647058824
# 0.02                3.97029702970297

# %%
f_x = (1 - cos(x)) / x
params = DEFAULT_PARAMS.copy()
params["ylim"] = (-1.1, 1.1)
plot(f_x, **params).show()
limit(f_x, x, 0)
# Out:
#   <div class="bk-root" id="2dd52460-15fc-4047-a158-a740e4da9543" data-root-id="1432"></div>
# 0

# %%
f_x = cos(pi/ x)
params = DEFAULT_PARAMS.copy()
params["ylim"] = (-1.1, 1.1)
params["xlim"] = (-1, 1)
plot(f_x, **params).show()
limit(f_x, x, 0)
# Out:
#   <div class="bk-root" id="6b86fd26-ba70-4053-9469-bbb5367e282f" data-root-id="2314"></div>
# AccumBounds(-1, 1)

# %%
limit(f_x, x, 0, "-")
# Out:
# AccumBounds(-1, 1)
