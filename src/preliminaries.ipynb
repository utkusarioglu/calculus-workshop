# %%
from sympy import (
    symbols,
    solve,
    N,
    sin,
    cos,
    pi,
    sqrt,
    E,
    log,
    Abs,
    gamma,
    tan,
    solveset,
)
from sympy.abc import x, y, i, t
import matplotlib.pyplot as plt
from spb import plot, plot_parametric
from spb.defaults import cfg, set_defaults
import numpy as np

cfg["backend_2D"] = "bokeh"
cfg["bokeh"]["theme"] = "dark_minimal"
cfg["bokeh"]["sizing_mode"] = "fixed"
cfg["bokeh"]["minor_grid_line_alpha"] = 0.1
set_defaults(cfg)
# Out:
# /opt/conda/envs/default/lib/python3.10/site-packages/spb/defaults.py:259: UserWarning: Successfully written settings to /home/math/.local/share/spb/config.json
#   warnings.warn("Successfully written settings to {}".format(file_path))

# %%
DEFAULT_PARAMS = {
    "xlim": (-10, 10),
    "ylim": (-10, 10),
    "aspect": "equal",
    # "size": (7.3, 5),
    "show": False,
    "detect_poles": True
}

# %% [markdown]
# # Preliminaries
#
# ## Functions

# %%
# f_x = x**2
f_x = (x+4)/(2*x -5)

# %% [markdown]
# If the inverse of `f(x)` is `y` then solving `f(x) - y` for `x` gives
# you the inverse.

# %%
f_x_inv = [i.replace(y, x) for i in solve(f_x - y, x)]
f_x_inv
# Out:
# [(5*x + 4)/(2*x - 1)]

# %%
x_range = (x, -10, 10)
plot(
    (f_x, x_range),
    (f_x_inv[0], x_range), (x, x_range),
    **DEFAULT_PARAMS
).show()
# Out:
#   <div class="bk-root" id="c51df115-96fe-4ed4-9bd0-a7fc57a3df3b" data-root-id="4288"></div>

# %%
roots = solve(f_x - f_x_inv[0], x)
print(N(roots[0]))
roots[0]
# Out:
# -0.561552812808830
# 3/2 - sqrt(17)/2

# %% [markdown]
# ## Trig things

# %%
# Notice that the function has the same coefficient and factor as ylim
g_x = 2 * cos(x + y) - sqrt(3)
params = DEFAULT_PARAMS.copy()
params["xlim"] = (-pi, pi) 
params["ylim"] = tuple(np.array([-1.1, 1.1])* 2 - sqrt(3))
plot(*[g_x.subs(y, i) for i in range(0, 3)], **params).show()
# Out:
#   <div class="bk-root" id="cbe93f97-358c-4a5a-b7b4-32f9241efe2e" data-root-id="13001"></div>

# %% [markdown]
# ## Exponentiation

# %%
f_x = 2**x
g_x = 1/2**x
params = DEFAULT_PARAMS.copy()
params["ylim"] = (-1, 10)
plot((f_x), (g_x), (1), **params).show()
# Out:
#   <div class="bk-root" id="865a42db-4e14-4123-84b8-166d19b68b38" data-root-id="13578"></div>

# %%
solve(g_x, x)
# Out:
# []

# %% [markdown]
# ### Natural exponential

# %%
plot(E**x, x, **DEFAULT_PARAMS).show()
# Out:
#   <div class="bk-root" id="df943031-4f98-4b26-9e75-bdf920c2484b" data-root-id="5362"></div>

# %%
h_x = 1 - 5 * E**(1 - x /2)
# kwargs = {
#     "xlim": ,
#     "ylim": (-5, 10)
# }
# defaults.get_default_settings()
params = DEFAULT_PARAMS.copy()
params["xlim"] = (0, 10)
params["ylim"] = (-5, 10)
plot((h_x), (x), **params).show()
# Out:
#   <div class="bk-root" id="6d2ce4ff-5cf6-45b8-82d5-35dfc9057a3f" data-root-id="14169"></div>

# %%
N(solve(h_x, x)[0])
# Out:
# 5.21887582486820

# %% [markdown]
# ## Logarithms

# %%
log(16, 4)
# Out:
# 2

# %% [markdown]
# ## Common graphs

# %%
# Slope intercept form
f_x = -2/5*x +3
plot(f_x, **DEFAULT_PARAMS).show()
# Out:
#   <div class="bk-root" id="294f395c-9f09-4b4b-8019-1c53319f3dcc" data-root-id="14739"></div>

# %%
plot(Abs(x - 2), **DEFAULT_PARAMS).show()
# Out:
#   <div class="bk-root" id="29173690-be0f-4d76-aab8-1f88cded9c46" data-root-id="15287"></div>

# %%
plot(x**2 + 2*x + 3).show()
# Out:
#   <div class="bk-root" id="3ea568fe-0280-419b-9c37-9dada487a561" data-root-id="15845"></div>
#   <div class="bk-root" id="6066c5c1-de0e-436b-b8a2-91d98f26f0eb" data-root-id="15845"></div>

# %%
c1 = plot(x**2 - 6*x + 5, **DEFAULT_PARAMS)
c2 = plot(x**2 - 7*x + 7, **DEFAULT_PARAMS)
(c1 + c2).show()
# Out:
#   <div class="bk-root" id="fe716fc9-2fce-46ef-a9f2-5877602dba9a" data-root-id="16527"></div>

# %%
p = plot((y-5)*(y-1), **DEFAULT_PARAMS).show()
# Out:
#   <div class="bk-root" id="48745423-a927-4b58-b7b9-9c848e3a5ce3" data-root-id="17139"></div>

# %% [markdown]
# ## Discontinuities

# %%
p = plot(gamma(x), **DEFAULT_PARAMS).show()
# Out:
#   <div class="bk-root" id="c76135c0-0aa6-4f43-a2d2-dd97110dfb06" data-root-id="17729"></div>

# %%
params = DEFAULT_PARAMS.copy()
params["xlim"] = (-1.1, 1.1)
params["ylim"] = (-1.1, 1.1)
# params["aspect"] = True
plot_parametric(sin(t), cos(t), (t, -pi, pi), **params).show()
# Out:
#   <div class="bk-root" id="bafe638e-12be-4062-a976-144be7b9d560" data-root-id="19037"></div>

# %%
sol = solve(((x-2)**2 /9) + 4 * (y + 2) ** 2 -1, y)
params = DEFAULT_PARAMS.copy()
params["xlim"] = (-2, 6)
params["ylim"] = (-3, -1)
(plot((sol[0], y), **params) + plot(sol[1], **params)).show()
# Out:
#   <div class="bk-root" id="f8925f26-0ee2-4cdd-986d-f9a202459da2" data-root-id="19716"></div>

# %%
expr = ((x+1)**2 /9 ) - ((y-2)**2 / 4) - 1
solutions = solve(expr, x)
params = DEFAULT_PARAMS.copy()
sum([plot(sol, **params) for sol in solutions]).show()
print([N(sol.subs(y, 0)) for sol in solutions])
# Out:
#   <div class="bk-root" id="efa5e363-2084-43a6-b8cb-66927fbe9988" data-root-id="26727"></div>
# [-5.24264068711928, 3.24264068711929]

# %%
expr = sqrt(x)
params = DEFAULT_PARAMS.copy()
params["xlim"] = (0, 10)
params["ylim"] = (0, 6)
plot(expr, **params).show()
# Out:
#   <div class="bk-root" id="02fa96d4-81f5-41df-aef7-40eddcb7c550" data-root-id="29018"></div>

# %%
expr = tan(x)
roots = solveset(expr)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 3
#       1 expr = tan(x)
#       2 roots = solveset(expr)
# ----> 3 plot(roots).show()
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/spb/functions.py:677, in plot(*args, **kwargs)
#     675 labels = kwargs.pop("label", [])
#     676 rendering_kw = kwargs.pop("rendering_kw", None)
# --> 677 series = _build_line_series(*plot_expr, **kwargs)
#     678 _set_labels(series, labels, rendering_kw)
#     679 series += _create_generic_data_series(**kwargs)
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/spb/functions.py:219, in _build_line_series(*args, **kwargs)
#     217         if not callable(expr):
#     218             arg = _process_summations(sum_bound, *arg)
# --> 219         series.append(LineOver1DRangeSeries(*arg[:-1], **kw))
#     220 return series
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/spb/series.py:1241, in LineOver1DRangeSeries.__init__(self, expr, var_start_end, label, **kwargs)
#    1239 def __init__(self, expr, var_start_end, label="", **kwargs):
#    1240     super().__init__(**kwargs)
# -> 1241     self.expr = expr if callable(expr) else sympify(expr)
#    1242     self._label = str(self.expr) if label is None else label
#    1243     self._latex_label = latex(self.expr) if label is None else label
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/spb/series.py:578, in BaseSeries.expr(self, e)
#     576 """Set the expression (or expressions) of the series."""
#     577 is_iter = hasattr(e, "__iter__")
# --> 578 is_callable = callable(e) if not is_iter else any(callable(t) for t in e)
#     579 if is_callable:
#     580     self._expr = e
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/spb/series.py:578, in <genexpr>(.0)
#     576 """Set the expression (or expressions) of the series."""
#     577 is_iter = hasattr(e, "__iter__")
# --> 578 is_callable = callable(e) if not is_iter else any(callable(t) for t in e)
#     579 if is_callable:
#     580     self._expr = e
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/utilities/iterables.py:2881, in roundrobin(*iterables)
#    2879 try:
#    2880     for nxt in nexts:
# -> 2881         yield nxt()
#    2882 except StopIteration:
#    2883     pending -= 1
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/sets/fancysets.py:414, in ImageSet.__iter__(self)
#     412 already_seen = set()
#     413 for i in self.base_pset:
# --> 414     val = self.lamda(*i)
#     415     if val in already_seen:
#     416         continue
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/core/function.py:2049, in Lambda.__call__(self, *args)
#    2041     raise BadArgumentsError(temp % {
#    2042         'name': self,
#    2043         'args': list(self.nargs)[0],
#    2044         'plural': 's'*(list(self.nargs)[0] != 1),
#    2045         'given': n})
#    2047 d = self._match_signature(self.signature, args)
# -> 2049 return self.expr.xreplace(d)
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/core/basic.py:1187, in Basic.xreplace(self, rule)
#    1125 def xreplace(self, rule):
#    1126     """
#    1127     Replace occurrences of objects within the expression.
#    1128
#    (...)
#    1185
#    1186     """
# -> 1187     value, _ = self._xreplace(rule)
#    1188     return value
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/core/basic.py:1209, in Basic._xreplace(self, rule)
#    1207     args = tuple(args)
#    1208     if changed:
# -> 1209         return self.func(*args), True
#    1210 return self, False
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/core/operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File /opt/conda/envs/default/lib/python3.10/site-packages/sympy/core/add.py:203, in Add.flatten(cls, seq)
#     186 """
#     187 Takes the sequence "seq" of nested Adds and returns a flatten list.
#     188
#    (...)
#     200
#     201 """
#     202 from sympy.calculus.accumulationbounds import AccumBounds
# --> 203 from sympy.matrices.expressions import MatrixExpr
#     204 from sympy.tensor.tensor import TensExpr
#     205 rv = None
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:
